# %%
lst = ['3','34','10']
result = map(int,lst)
list(result)
# Out:
# [3, 34, 10]

# %%
def myreplace(s):
    return s.replace(',','')

lst = ['34000','1999','2786','1000000']
result = map(myreplace,lst)
list(result)
# Out:
# ['34000', '1999', '2786', '1000000']

# %%
lst = ['34000','1000','2700']

# %%
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0,5,0.2)
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
plt.show()

# %%
import numpy
print(numpy.sqrt(2))
# Out:
# 1.4142135623730951

# %%
import numpy as np
print(np.sqrt(2))
# Out:
# 1.4142135623730951

# %%
import numpy as np
print(np.pi)
print(np.sin(0))
print(np.cos(np.pi))
# Out:
# 3.141592653589793
# 0.0
# -1.0

# %%
import numpy as np
a= np.random.rand(5)
print(a)
print(type(a))
# Out:
# [0.7443921  0.43814121 0.49680356 0.85666037 0.61226204]
# <class 'numpy.ndarray'>

# %%
import numpy as np
print(np.random.choice(6,10))
# Out:
# [4 5 0 0 0 0 4 5 0 1]

# %%
import numpy as np
print (np.random.choice(10,6,replace=False))
# Out:
# [6 3 2 1 9 7]

# %%
import numpy as np
print(np.random.choice(6,10,p=[0.1,0.2,0.3,0.2,0.1,0.1]))
# Out:
# [2 3 4 3 1 4 2 4 2 0]

# %%
import matplotlib.pyplot as plt
import numpy as np

dice = np.random.choice(6,10)

plt.hist(dice,bins=6)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

dice = []
for i in range(10):
    dice.append(random.randint(1,6))

plt.hist(dice,bins=6)
plt.show()

# %%
import matplotlib.pyplot as pltimport numpy as np
dice =np.random.choice (6,1000000,p=[0.1])
