# %% [markdown]
# <a href="https://colab.research.google.com/github/won462/2023-A-DA/blob/main/week03-seoul-temperature-won462.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 서울 기온 분석

# %% [markdown]
# ## 파이썬 설치 점검

# %%
import site

# %%
site.getsitepackages()
# Out:
# ['C:\\Users\\102\\anaconda3', 'C:\\Users\\102\\anaconda3\\lib\\site-packages']

# %% [markdown]
# ## csv 파일 읽기

# %%
import csv
# f= open("seoul.csv","r",eccoding="cp949")
f= open("seoul.csv")
data=csv.reader(f)
print(data)
for row in data:
    print (row)
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-4f83afe628e9> in <cell line: 3>()
#       1 import csv
#       2 # f= open("seoul.csv","r",eccoding="cp949")
# ----> 3 f= open("seoul.csv")
#       4 data=csv.reader(f)
#       5 print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seoul.csv'

# %%
import csv
f= open("seoul.csv")
data=csv.reader(f)
for row in data:
    if ''in row:
        print(row)
f.close()
# Out:
# ['\t1950-09-01', '108', '', '', '']
# ['\t1950-09-02', '108', '', '', '']
# ['\t1950-09-03', '108', '', '', '']
# ['\t1950-09-04', '108', '', '', '']
# ['\t1950-09-05', '108', '', '', '']
# ['\t1950-09-06', '108', '', '', '']
# ['\t1950-09-07', '108', '', '', '']
# ['\t1950-09-08', '108', '', '', '']
# ['\t1950-09-09', '108', '', '', '']
# ['\t1950-09-10', '108', '', '', '']
# ['\t1950-09-11', '108', '', '', '']
# ['\t1950-09-12', '108', '', '', '']
# ['\t1950-09-13', '108', '', '', '']
# ['\t1950-09-14', '108', '', '', '']
# ['\t1950-09-15', '108', '', '', '']
# ['\t1950-09-16', '108', '', '', '']
# ['\t1950-09-17', '108', '', '', '']
# ['\t1950-09-18', '108', '', '', '']
# ['\t1950-09-19', '108', '', '', '']
# ['\t1950-09-20', '108', '', '', '']
# ['\t1950-09-21', '108', '', '', '']
# ['\t1950-09-22', '108', '', '', '']
# ['\t1950-09-23', '108', '', '', '']
# ['\t1950-09-24', '108', '', '', '']
# ['\t1950-09-25', '108', '', '', '']
# ['\t1950-10-01', '108', '', '', '']
# ...

# %%
import csv
f= open("seoul.csv")
data=csv.reader(f)
header=next(data)
print (header)
for row in data:
    row[4]=float(row[4])
    print (row)
    break
f.close()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
# ['\t1907-10-01', '108', '13.5', '7.9', 20.7]
